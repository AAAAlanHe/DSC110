# %% [markdown]
# <a href="https://colab.research.google.com/github/AAAAlanHe/DSC110/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello Word")
# Out:
# Hello Word

# %% [markdown]
# out put "Hello Word"

# %% [markdown]
# # variables
# in this section, we will discuss variables

# %%
a = "MCPHS"

# %% [markdown]
# assign a as mcphs

# %%
print(a)
# Out:
# MCPHS

# %% [markdown]
# output a

# %%
b = "Boston"

# %% [markdown]
# assign b

# %%
print(b)
# Out:
# Boston

# %% [markdown]
# output b

# %%
print(a[0])
# Out:
# M

# %% [markdown]
# out put the first digit of a

# %%
b = 2
c = 3
d = b + c
print(d)
# Out:
# 5

# %% [markdown]
# calculate 2+3

# %%
type(d)
# Out:
# int

# %% [markdown]
# the data type of d is integer

# %%
type(a)
# Out:
# str

# %% [markdown]
# a is string

# %%
5**2
# Out:
# 25

# %% [markdown]
# calculate 5*5

# %%
print(5**2)
# Out:
# 25

# %% [markdown]
# output the result

# %% [markdown]
# # Lists

# %%
My_List = (1,2,3,4,5,a)

# %% [markdown]
# make a list

# %%
print(My_List)
# Out:
# (1, 2, 3, 4, 5, 'MCPHS')

# %% [markdown]
# print the list

# %%
My_List[1]
# Out:
# 2

# %% [markdown]
# the second of the list

# %% [markdown]
# # Tuple

# %%
My_Tuple=(1,2,3,4,5)

# %% [markdown]
# make a tuple

# %%
print(My_Tuple)
# Out:
# (1, 2, 3, 4, 5)

# %% [markdown]
# print the tuple

# %%
print(My_Tuple[1])
# Out:
# 2

# %% [markdown]
# the second of the tuple

# %% [markdown]
# # Dictionary

# %%
My_Dictionary={
    "Name":"Heather",
    "Age":"35",
    "Gender":"Female",
    "city":"Boston"
}

# %% [markdown]
# assign the information to the dictionary

# %%
My_Dictionary['Name']
# Out:
# 'Heather'

# %% [markdown]
# output the name in dictionary

# %% [markdown]
# # Sets

# %%
My_Set={1,2,3,4,5,5}

# %% [markdown]
# make a set

# %%
print(My_Set)
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# print the set

# %%
print(My_Set[1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1425231570.py in <cell line: 0>()
# ----> 1 print(My_Set[1])
#
# TypeError: 'set' object is not subscriptable

# %% [markdown]
# cannot access by position

# %% [markdown]
# # Functions

# %%
Temp = (4*9/5)+32
print(Temp)
# Out:
# 39.2

# %% [markdown]
# cauculate f of 4c

# %%
temp=(-6*9/5)+32
print(temp)
# Out:
# 21.2

# %% [markdown]
# -6c

# %%
def c_to_f(c_temp):
  f_temp=(c_temp*9/5)+32
  return f_temp

# %% [markdown]
# define a function to calculate the temperature

# %%
f_temp=c_to_f(4)
# Out:
# 39.2

# %% [markdown]
# use the function

# %% [markdown]
# # Formattied String Leterals

# %%
print(f"the temperature is {c_to_f(0)}F")
# Out:
# the temperature is 32.0F

# %% [markdown]
# print the result in a full sentence

# %% [markdown]
# # Loops

# %%
My_Temp_List_C = [0,10,20,30,40]

# %% [markdown]
# make a list for the original data

# %%
c_to_f(0)
c_to_f(10)
# Out:
# 50.0

# %% [markdown]
# calculate some of the data

# %%
for c_temp in My_Temp_List_C:
 print(c_to_f(c_temp))
# Out:
# 32.0
# 50.0
# 68.0
# 86.0
# 104.0

# %% [markdown]
# use for loop to calculate all the datas in the list

# %% [markdown]
# # Exercise

# %%
def calculate_BMI(weight_kg,height_m):
  BMI=weight_kg/height_m**2
  return BMI

# %% [markdown]
# define a function to calculate BMI

# %%
calculate_BMI(weight_kg=70,height_m=1.75)
# Out:
# 22.857142857142858

# %% [markdown]
# use the function to calculate BMI for a person 70kg and 1.75m

# %%
BMI=18
if BMI<20:
  print("underweight")
else:
  print("normal")
# Out:
# underweight

# %% [markdown]
# use if and else to output the result of BMI is normal or not

# %% [markdown]
# # libraries

# %%
import pandas as pdd
import numpy as np

# %% [markdown]
# some database in python

# %%
sum_c=sum(My_Temp_List_C)
print(c)
# Out:
# 3

# %% [markdown]
# use of the database
